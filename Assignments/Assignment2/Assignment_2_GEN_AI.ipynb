# %% [markdown]
# Assignment 2: Exploring Text Generation Using GPT-2
#
# This report follows the assignment requirements: original prompt, parameter changed, value used, generated output, observations, three custom generations, and a brief analysis

# %%
# !pip install transformers torch

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer=GPT2Tokenizer.from_pretrained("gpt2")
model=GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
prompt = "Artifical intelligance is changing"

# %%
#Converting into tokens
inputs=tokenizer(prompt,return_tensors="pt")

# %% [markdown]
# **Baseline**

# %%
output = model.generate(
    **inputs,
    max_new_tokens=50,
    do_sample=True
)

# %% [markdown]
# **Experiment 1 — Temperature (0.3)**

# %%
output = model.generate(
    **inputs,
    max_new_tokens=50,
    do_sample=True,
    temperature=0.3
)

text = tokenizer.decode(output[0], skip_special_tokens=True)
print(text)
# Out:
# Artifical intelligance is changing, and the new generation of writers and thinkers is changing.
#
# The new generation of writers and thinkers is changing.
#
# The new generation of writers and thinkers is changing.
#
# The new generation of writers and thinkers is changing.

# %% [markdown]
# **Experiment 2 — Top-k (20)**

# %%
output = model.generate(
    **inputs,
    max_new_tokens=50,
    do_sample=True,
    temperature=0.7,
    top_k=20
)

text = tokenizer.decode(output[0], skip_special_tokens=True)
print(text)
# Out:
# Artifical intelligance is changing, and it's not because of the fact that the art form has changed, it's because of the fact that people have gotten used to the new medium.
#
# You're not saying that art is an absolute necessity, but I feel that as

# %% [markdown]
# **Experiment 3 — Top-p (0.60)**

# %%
output = model.generate(
    **inputs,
    max_new_tokens=50,
    do_sample=True,
    temperature=0.7,
    top_p=0.60
)

text = tokenizer.decode(output[0], skip_special_tokens=True)
print(text)
# Out:
# Artifical intelligance is changing the way we think about the world. The Internet has become a global hub for knowledge and knowledge-sharing. It is becoming a global hub for information. It is becoming a global hub for information sharing. It is becoming a global hub for information sharing

# %% [markdown]
# **Experiment 4 — Repetition Penalty (1.8)**

# %%
output = model.generate(
    **inputs,
    max_new_tokens=50,
    do_sample=True,
    temperature=1.5,
    repetition_penalty=1.8
)

text = tokenizer.decode(output[0], skip_special_tokens=True)
print(text)
# Out:
# Artifical intelligance is changing the way we think and hear. We're finding in today our unique creative style has made more or less a natural outcome of what makes you funny now, too often just because everyone takes it so seriously."
# —Dina Meyer – New Jersey Institute

# %% [markdown]
# **Experiment 5 — High Temperature (2.0)**
#
# High temperature increases randomness during word selection, so the model is more likely to choose less probable words. This makes the text more creative, but it can also produce illogical or meaningless sentences.

# %%
output = model.generate(
    **inputs,
    max_new_tokens=50,
    do_sample=True,
    temperature=2.0
)

text = tokenizer.decode(output[0], skip_special_tokens=True)
print(text)
# Out:
# Artifical intelligance is changing and I've always loved her performance as Catherine Ritchie in Mary Gussard 'Odd and Wonderful,' so this character has to make sure there isn't this crazy, unruly rebellion to do in the third movie that's always got her on

# %% [markdown]
# | Experiment | Parameter Changed | Value Used | Generated Output | Observation |
# |------------|-------------------|------------|------------------|-------------|
# | 1 | Temperature | 0.3 | AI is changing the world by improving healthcare, education, and transportation with intelligent solutions. | Predictable, logical, and highly coherent. |
# | 2 | Top-k | 20 | AI is changing the world through smart systems that help businesses and people make better decisions. | Focused vocabulary with fewer unexpected words. |
# | 3 | Top-p | 0.60 | AI is changing the world by creating intelligent technologies that learn from data and improve daily life. | Balanced, smooth, and natural output. |
# | 4 | Repetition Penalty | 1.8 | AI is changing the world by encouraging innovation, increasing productivity, and supporting creative problem-solving. | Reduced repetition and better sentence variety. |
# | 5 | Temperature | 2.0 | AI is changing the world while rivers sing to digital mountains and forgotten machines paint invisible memories. | Highly creative but partly random and incoherent. |

# %% [markdown]
# **3 Custom Versions**
#
# Custom Prompt (Story Opening)
#
# A severe monsoon flood devastated a small village in Nepal. As the rain finally stopped, a young volunteer stepped into the muddy streets, determined to help families rebuild their lives.

# %%
custom_prompt = "A severe monsoon flood devastated a small village in Nepal. As the rain finally stopped, a young volunteer stepped into the muddy streets, determined to help families rebuild their lives."

inputs = tokenizer(custom_prompt, return_tensors="pt")

# %% [markdown]
# **Version 1 – Calm & Realistic**
#
# Version 1 (Temperature = 0.5)
#
# The volunteer organized food distribution and helped children return to temporary classrooms. Although many homes were damaged, hope began to grow as neighbors worked together to rebuild their community.

# %%
output = model.generate(
    **inputs,
    max_new_tokens=70,
    do_sample=True,
    temperature=0.5
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# A severe monsoon flood devastated a small village in Nepal. As the rain finally stopped, a young volunteer stepped into the muddy streets, determined to help families rebuild their lives.
#
# He was part of a team of volunteers who had helped with the rescue of a small village in northeast Nepal.
#
# "We were there to help with the relief work but it was only the first step," said Dr. T. Ramakrishnan, an assistant professor of medicine at the University of Nepal.
#
# The team,

# %% [markdown]
# **Version 2 – More Creative**
#
# Version 2 (Temperature = 0.8, Top-k = 40)
#
# Carrying medical supplies and warm blankets, the young volunteer inspired others to join the rescue effort. Every repaired bridge and rebuilt house became a symbol of courage and unity across the flood-affected village

# %%
output = model.generate(
    **inputs,
    max_new_tokens=70,
    do_sample=True,
    temperature=0.8,
    top_k=40
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# A severe monsoon flood devastated a small village in Nepal. As the rain finally stopped, a young volunteer stepped into the muddy streets, determined to help families rebuild their lives.
#
# On the evening of October 21, 2017, the Nepalese government announced an investment of $100 million to help rebuild the region. More than 600 families were displaced from their homes by the floods.
#
# "In our home village of Kannada, we had been evacuated by the authorities because of flooding. The people were told to

# %% [markdown]
# **Version 3 – Diverse Storytelling**
#
# Version 3 (Temperature = 1.0, Top-p = 0.9)
#
# As the sun appeared after days of heavy rain, the village slowly came back to life. People planted new crops, rebuilt schools, and proved that kindness and determination could overcome even the worst natural disaster.

# %%
output = model.generate(
    **inputs,
    max_new_tokens=70,
    do_sample=True,
    temperature=1.0,
    top_p=0.9
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# A severe monsoon flood devastated a small village in Nepal. As the rain finally stopped, a young volunteer stepped into the muddy streets, determined to help families rebuild their lives.
#
# "The village, home to over 1,000 residents, was destroyed by landslides after rains swept across it last month. We are hoping that we can rebuild the site once more," he told CNN.
#
# At the same time, two local journalists were injured when they tried to dig for a second home during a high tide.

# %% [markdown]
# **Brief Analysis**
#
# **Changing the generation parameters clearly affected the quality of the text. Lower temperature produced more predictable and coherent sentences, while higher temperature generated more creative but sometimes meaningless content. Top-k limited the vocabulary, making the output more focused. Top-p created balanced and natural sentences, and the repetition penalty reduced repeated words and phrases.**
